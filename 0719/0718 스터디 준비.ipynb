# %% [markdown]
# # 4673번

# %% [markdown]
# 셀프 넘버는 1949년 인도 수학자 D.R. Kaprekar가 이름 붙였다. 양의 정수 n에 대해서 d(n)을 n과 n의 각 자리수를 더하는 함수라고 정의하자. 예를 들어, d(75) = 75+7+5 = 87이다.
#
# 양의 정수 n이 주어졌을 때, 이 수를 시작해서 n, d(n), d(d(n)), d(d(d(n))), ...과 같은 무한 수열을 만들 수 있다.
#
# 예를 들어, 33으로 시작한다면 다음 수는 33 + 3 + 3 = 39이고, 그 다음 수는 39 + 3 + 9 = 51, 다음 수는 51 + 5 + 1 = 57이다. 이런식으로 다음과 같은 수열을 만들 수 있다.
#
# 33, 39, 51, 57, 69, 84, 96, 111, 114, 120, 123, 129, 141, ...
#
# n을 d(n)의 생성자라고 한다. 위의 수열에서 33은 39의 생성자이고, 39는 51의 생성자, 51은 57의 생성자이다. 생성자가 한 개보다 많은 경우도 있다. 예를 들어, 101은 생성자가 2개(91과 100) 있다.
#
# 생성자가 없는 숫자를 셀프 넘버라고 한다. 100보다 작은 셀프 넘버는 총 13개가 있다. 1, 3, 5, 7, 9, 20, 31, 42, 53, 64, 75, 86, 97
#
# 10000보다 작거나 같은 셀프 넘버를 한 줄에 하나씩 출력하는 프로그램을 작성하시오.

# %% [markdown]
# https://www.acmicpc.net/problem/4673

# %% [markdown]
# # 실패본 1

# %%
def selfnumber(a):
    a = str()
    for i in range(0,6):
        a = int(a) + int(a[i])
        if i >= len(a):
            break
        return int(a)

# %%
notselfnumber=[]

for a in range(1,10001):
    a = str(a)
    for i in a:
        a = int(a) + int(i)
        notselfnumber.append(a)

# %%
selfnumber(245)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-1545f6daa034> in <module>
# ----> 1 selfnumber(245)
#
# <ipython-input-138-c4ffb7743f85> in selfnumber(a)
#       2     a = str()
#       3     for i in range(0,6):
# ----> 4         a = int(a) + int(a[i])
#       5         if i >= len(a):
#       6             break
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = str(134)
print(a[1])
len(a)
# Out:
# 3
# 3

# %% [markdown]
# # map 함수를 어떻게 쓰는지 모르겠닷,,!

# %% [markdown]
# #### (map은 list등의 형태로 감싸줘야 출력이 가능하다)

# %%
int(a)+map(int,[a[i] for i in range(5)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-eca0c4ef3a73> in <module>
# ----> 1 int(a)+map(int,[a[i] for i in range(5)])
#
# <ipython-input-90-eca0c4ef3a73> in <listcomp>(.0)
# ----> 1 int(a)+map(int,[a[i] for i in range(5)])
#
# IndexError: string index out of range

# %%
a = str(132)
print(a[2])
# Out:
# 2

# %%
range(1, 10)
# Out:
# range(1, 10)

# %%
list(range(1, 10))
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## 추가공부 1
#
# ### ㄴ딕셔너리 자료형은 포문에 넣었을 때 key값으로 돌아간다!!!!!
# ### for 문에 뭐 넣을 수 있는지 잘 파악해야 할 듯!

# %% [markdown]
# ## -----------------------------------------------------------------
#
#
# ## 추가공부 2
#
# ## list comprehension = 위의 세 줄 문법과 아래 한 줄 문법이 동일하다
#
#
# #### lst = []
# #### for i in x:
#    #### lst.append(x[i])
#
#
# #### -----------------------------------------------------------------
#
#
# #### [x[i] for i in x]

# %% [markdown]
# ## 추가공부 3
#
# ## lambda = 함수에 대해 따로 정의할 필요 없이 한 방에 쓸 수 있는 기능
#
# #### x={1:10,2:20,3:30}
# #### list(map(lambda a: a*2 ,[x[i] for i in x]))
#
#
# #### x={1:10,2:20,3:30}
# #### list(map(lambda a: a*4 ,[x[i] for i in x]))
#
# #### x={1:10,2:20,3:30}
# #### list(map(lambda a: a/2 ,[x[i] for i in x]))
#
# #### 만약 자료형이 list형이라면,,!! x = [1 , 3,  5, 7, 9]
# #### [ i for i in x ] 형태로 써야함!
#
# #### [x[i] for i in x ]가 아니라!!
#
# ## -----------------------------------------------------------------

# %% [markdown]
# # 성공!
#
# str 형식으로 만들 때 알아서list 형이 되는 듯 하다.

# %%
selfnumber=[]
for i in range(1,10001):
    for j in str(i):
        i = int(j)+i
    selfnumber.append(i)

# %%
for a in range(1,10001):
    if a not in selfnumber:
        print(a)
# Out:
# 1
# 3
# 5
# 7
# 9
# 20
# 31
# 42
# 53
# 64
# 75
# 86
# 97
# 108
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 211
# 222
# 233
# 244
# 255
# 266
# 277
# 288
# 299
# 310
# 312
# 323
# 334
# 345
# 356
# 367
# 378
# 389
# 400
# 411
# 413
# 424
# 435
# 446
# 457
# 468
# 479
# 490
# 501
# 512
# 514
# 525
# 536
# 547
# 558
# 569
# 580
# 591
# 602
# 613
# 615
# 626
# 637
# 648
# 659
# 670
# 681
# 692
# 703
# 714
# 716
# 727
# 738
# 749
# 760
# 771
# 782
# 793
# 804
# 815
# 817
# 828
# 839
# 850
# 861
# 872
# 883
# 894
# 905
# 916
# 918
# 929
# 940
# 951
# 962
# 973
# 984
# 995
# 1006
# 1021
# 1032
# 1043
# 1054
# 1065
# 1076
# 1087
# 1098
# 1109
# 1111
# 1122
# 1133
# 1144
# 1155
# 1166
# 1177
# 1188
# 1199
# 1210
# 1212
# 1223
# 1234
# 1245
# 1256
# 1267
# 1278
# 1289
# 1300
# 1311
# 1313
# 1324
# 1335
# 1346
# 1357
# 1368
# 1379
# 1390
# 1401
# 1412
# 1414
# 1425
# 1436
# 1447
# 1458
# 1469
# 1480
# 1491
# 1502
# 1513
# 1515
# 1526
# 1537
# 1548
# 1559
# 1570
# 1581
# 1592
# ...

# %%
a=str(123)
a[0]
# Out:
# '1'

# %% [markdown]
# ## 현수오빠 답

# %%
check = [False] * 10001
for i in range(1,10001):
    k = i
    for j in str(i):
        k += int(j)
    if k < 10001:
        check[k] = True
        
for i in range(1,10001):
    if check[i] == False:
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 20
# 31
# 42
# 53
# 64
# 75
# 86
# 97
# 108
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 211
# 222
# 233
# 244
# 255
# 266
# 277
# 288
# 299
# 310
# 312
# 323
# 334
# 345
# 356
# 367
# 378
# 389
# 400
# 411
# 413
# 424
# 435
# 446
# 457
# 468
# 479
# 490
# 501
# 512
# 514
# 525
# 536
# 547
# 558
# 569
# 580
# 591
# 602
# 613
# 615
# 626
# 637
# 648
# 659
# 670
# 681
# 692
# 703
# 714
# 716
# 727
# 738
# 749
# 760
# 771
# 782
# 793
# 804
# 815
# 817
# 828
# 839
# 850
# 861
# 872
# 883
# 894
# 905
# 916
# 918
# 929
# 940
# 951
# 962
# 973
# 984
# 995
# 1006
# 1021
# 1032
# 1043
# 1054
# 1065
# 1076
# 1087
# 1098
# 1109
# 1111
# 1122
# 1133
# 1144
# 1155
# 1166
# 1177
# 1188
# 1199
# 1210
# 1212
# 1223
# 1234
# 1245
# 1256
# 1267
# 1278
# 1289
# 1300
# 1311
# 1313
# 1324
# 1335
# 1346
# 1357
# 1368
# 1379
# 1390
# 1401
# 1412
# 1414
# 1425
# 1436
# 1447
# 1458
# 1469
# 1480
# 1491
# 1502
# 1513
# 1515
# 1526
# 1537
# 1548
# 1559
# 1570
# 1581
# 1592
# ...

# %% [markdown]
# ## 지상이 답

# %%
def sum(a):
    s = a
    while(a>0):
        s += a%10
        a=a//10
    return s
list=[]
for i in range(0,10001):
    list.append(0)
for i in range(1,10001):
    cnt=sum(i)
    if(cnt<10001):
        list[cnt]=1
for i in range(1,10001):
    if(list[i]==0):
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 20
# 31
# 42
# 53
# 64
# 75
# 86
# 97
# 108
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 211
# 222
# 233
# 244
# 255
# 266
# 277
# 288
# 299
# 310
# 312
# 323
# 334
# 345
# 356
# 367
# 378
# 389
# 400
# 411
# 413
# 424
# 435
# 446
# 457
# 468
# 479
# 490
# 501
# 512
# 514
# 525
# 536
# 547
# 558
# 569
# 580
# 591
# 602
# 613
# 615
# 626
# 637
# 648
# 659
# 670
# 681
# 692
# 703
# 714
# 716
# 727
# 738
# 749
# 760
# 771
# 782
# 793
# 804
# 815
# 817
# 828
# 839
# 850
# 861
# 872
# 883
# 894
# 905
# 916
# 918
# 929
# 940
# 951
# 962
# 973
# 984
# 995
# 1006
# 1021
# 1032
# 1043
# 1054
# 1065
# 1076
# 1087
# 1098
# 1109
# 1111
# 1122
# 1133
# 1144
# 1155
# 1166
# 1177
# 1188
# 1199
# 1210
# 1212
# 1223
# 1234
# 1245
# 1256
# 1267
# 1278
# 1289
# 1300
# 1311
# 1313
# 1324
# 1335
# 1346
# 1357
# 1368
# 1379
# 1390
# 1401
# 1412
# 1414
# 1425
# 1436
# 1447
# 1458
# 1469
# 1480
# 1491
# 1502
# 1513
# 1515
# 1526
# 1537
# 1548
# 1559
# 1570
# 1581
# 1592
# ...

# %%
def d(n):
    a=str(n)
    li=[int(i) for i in a]
    b= n + sum(li)
    return b

def repeat():
    li=[]
    for i in range(1,10001):
        li.append(d(i))
    for i in range(1, 10001):
        if i not in li:
            print(i)

repeat()
# Out:
# 1
# 3
# 5
# 7
# 9
# 20
# 31
# 42
# 53
# 64
# 75
# 86
# 97
# 108
# 110
# 121
# 132
# 143
# 154
# 165
# 176
# 187
# 198
# 209
# 211
# 222
# 233
# 244
# 255
# 266
# 277
# 288
# 299
# 310
# 312
# 323
# 334
# 345
# 356
# 367
# 378
# 389
# 400
# 411
# 413
# 424
# 435
# 446
# 457
# 468
# 479
# 490
# 501
# 512
# 514
# 525
# 536
# 547
# 558
# 569
# 580
# 591
# 602
# 613
# 615
# 626
# 637
# 648
# 659
# 670
# 681
# 692
# 703
# 714
# 716
# 727
# 738
# 749
# 760
# 771
# 782
# 793
# 804
# 815
# 817
# 828
# 839
# 850
# 861
# 872
# 883
# 894
# 905
# 916
# 918
# 929
# 940
# 951
# 962
# 973
# 984
# 995
# 1006
# 1021
# 1032
# 1043
# 1054
# 1065
# 1076
# 1087
# 1098
# 1109
# 1111
# 1122
# 1133
# 1144
# 1155
# 1166
# 1177
# 1188
# 1199
# 1210
# 1212
# 1223
# 1234
# 1245
# 1256
# 1267
# 1278
# 1289
# 1300
# 1311
# 1313
# 1324
# 1335
# 1346
# 1357
# 1368
# 1379
# 1390
# 1401
# 1412
# 1414
# 1425
# 1436
# 1447
# 1458
# 1469
# 1480
# 1491
# 1502
# 1513
# 1515
# 1526
# 1537
# 1548
# 1559
# 1570
# 1581
# 1592
# ...

# %%
def d(n):
    a=str(n)
    li=[int(i) for i in a]
    b= n + sum(li)
    return b

d(134)
# Out:
# 142

# %% [markdown]
# # --------------------------------------------------------

# %% [markdown]
# # 2908번

# %% [markdown]
# 상근이의 동생 상수는 수학을 정말 못한다. 상수는 숫자를 읽는데 문제가 있다. 이렇게 수학을 못하는 상수를 위해서 상근이는 수의 크기를 비교하는 문제를 내주었다. 상근이는 세 자리 수 두 개를 칠판에 써주었다. 그 다음에 크기가 큰 수를 말해보라고 했다.
#
# 상수는 수를 다른 사람과 다르게 거꾸로 읽는다. 예를 들어, 734와 893을 칠판에 적었다면, 상수는 이 수를 437과 398로 읽는다. 따라서, 상수는 두 수중 큰 수인 437을 큰 수라고 말할 것이다.
#
# 두 수가 주어졌을 때, 상수의 대답을 출력하는 프로그램을 작성하시오.
#
# 입력
# 첫째 줄에 상근이가 칠판에 적은 두 수 A와 B가 주어진다. 두 수는 같지 않은 세 자리 수이며, 0이 포함되어 있지 않다.
#
#
# # 왜 틀린거임?
# ## https://www.acmicpc.net/problem/2908

# %%
a,b = map(str, input().split())

if a[2] > b[2]:
    print (''.join(reversed(a)))
elif a[2] == b[2]:
    if a[1] > b[1]:
        print (''.join(reversed(a)))
    elif a[1] == b[1]:
        if a[0]>b[0]:
            print (''.join(reversed(a)))
else:
    print (''.join(reversed(b)))
# Out:
# 572 329
# 923

# %% [markdown]
# # 2588번

# %% [markdown]
# (세 자리 수) × (세 자리 수)는 다음과 같은 과정을 통하여 이루어진다.
#
#
#
# (1)과 (2)위치에 들어갈 세 자리 자연수가 주어질 때 (3), (4), (5), (6)위치에 들어갈 값을 구하는 프로그램을 작성하시오.

# %%
a=str(input())
b=str(input())

c = int(a)*int(b[2])
d = int(a)*int(b[1])
e = int(a)*int(b[0])

d_str = str(d)+"0"
e_str = str(e)+"00"


print(c)
print(d)
print(e)
print(c+int(d_str)+int(e_str))
# Out:
# 472
# 385
# 2360
# 3776
# 1416
# 181720
